# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import numpy as np
import cv2
# import pafy
from time import time


class ObjectDetection:
    """
    Class implements Yolov7 model to make inferences on a video using OpenCV.
    """
    
    def __init__(self, directory, out_file, bike_rider_model, helmet_npr_model):
        """
        Initializes the class with youtube url and output file.
        :param url: Has to be as youtube URL,on which prediction is made.
        :param out_file: A valid output file name.
        """
        self.directory = directory
        self.bike_rider_model = (bike_rider_model)
        self.helmet_npr_model = (helmet_npr_model)
        self.out_file = out_file
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print("\n\nDevice Used:",self.device)


    def load_bike_model(self, bike_rider_model):
        """
        Loads Yolov7 model from pytorch hub.
        :return: Trained Pytorch model.
        """
        model_bike = torch.hub.load('WongKinYiu/yolov7', 'custom', path_or_model=bike_rider_model, force_reload=True,trust_repo=True)
        return model_bike

    def load_npr_model(self, helmet_npr_model):
        """
        Loads Yolov7 model from pytorch hub.
        :return: Trained Pytorch model.
        """
        model_npr = torch.hub.load('WongKinYiu/yolov7', 'custom', path_or_model=helmet_npr_model, force_reload=True,trust_repo=True)
        self.classes = model_npr.names
        return model_npr


    def score_frame(self, frame):
        """
        Takes a single frame as input, and scores the frame using yolo5 model.
        :param frame: input frame in numpy/list/tuple format.
        :return: Labels and Coordinates of objects detected by model in the frame.
        """
        self.model_bike.to(self.device)    #runs on gpu 
        frame = [frame]
        results = self.model_bike(frame)   #bike riders prediction
     
        labels, cords = results.xyxyn[0][:, -1], results.xyxyn[0][:, :-1]  #predicted labels and coordinates
        detection_label = []         #list to store the results
        detection_result = []
        n = len(labels)
        x_shape, y_shape = frame[0].shape[1], frame[0].shape[0]  

        for i in range(n):       #loop on all bike riders in a frame 
            if cords[i,4]>0.5:   #Accept confidence level of 0.5 
                row = cords[i]
                y1, x1, y2, x2 = int(row[0]*x_shape), int(row[1]*y_shape), int(row[2]*x_shape), int(row[3]*y_shape)  #x and y coordinates pixels of bike riders in frame
                cropped_image = frame[0][x1:x2,y1:y2]       #cropping image of bike riders
                cropped_image = cv2.resize(cropped_image,(640,640))    #resizing the image
                cropped_image = [cropped_image]
                self.model_npr.to(self.device)  #runs on gpu
                results = self.model_npr(cropped_image)  #prediction of helmet and number plate for cropped bike rider image
                labels1, cords1 = results.xyxyn[0][:, -1], results.xyxyn[0][:, :-1]  #storing lables and co-ordinates
                n1 = len(labels1)
                if (0 in labels1) & (n>0):  #If any helmet is detected in bike rider image then number plate is not saved.
  
                    for j in range(n):
                      if (labels1[j]==0) & (cords1[j,4]>0.3):

                            detection_result.append(row) #Appending to results to draw bounding box
                            detection_label.append(0)
                            break
                else:
                  for j in range(n):
                    if (labels1[j]==1) & (cords1[j,4]>0.5): #If there are any bike rider with no helmet 

                        detection_result.append(row)   #Appending to results to draw bounding box
                        detection_label.append(1)

                        for k in range(n):
                          if (labels1[k]==2) & (cords1[k,4]>0.5):
                            row1 = cords1[k]
                            y1a, x1a, y2a, x2a = int(row1[0]*x_shape), int(row1[1]*y_shape), int(row1[2]*x_shape), int(row1[3]*y_shape)  #x and y coordinates pixels of bike riders in frame
                            number_plate_image = cropped_image[0][x1a:x2a,y1a:y2a]   
                            
                            time_stamp = str(time.time())
                            cv2.imwrite(f'number_plates/{time_stamp}_{cords1[k,4]}.jpg', number_plate_image) #saves number plate image
        return detection_label,detection_result



    def class_to_label(self, x):
        """
        For a given label value, return corresponding string label.
        :param x: numeric label
        :return: corresponding string label
        """
        return self.classes[int(x)]


    def plot_boxes(self, results, frame):
        """
        Takes a frame and its results as input, and plots the bounding boxes and label on to the frame.
        :param results: contains labels and coordinates predicted by model on the given frame.
        :param frame: Frame which has been scored.
        :return: Frame with bounding boxes and labels ploted on it.
        """
        labels, cord = results
        n = len(labels)
        x_shape, y_shape = frame.shape[1], frame.shape[0]
        for i in range(n):
            row = cord[i]
            
            x1, y1, x2, y2 = int(row[0]*x_shape), int(row[1]*y_shape), int(row[2]*x_shape), int(row[3]*y_shape)
            if labels[i]==0:
              bgr = (0, 255, 0)
            else:
              bgr = (0, 0, 255)
            cv2.rectangle(frame, (x1, y1), (x2, y2), bgr, 2)
            cv2.putText(frame, self.class_to_label(labels[i]), (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 0.9, bgr, 2)

        return frame


    def __call__(self):
        """
        This function is called when class is executed, it runs the loop to read the video frame by frame,
        and write the output into a new file.
        :return: void
        """
        player = cv2.VideoCapture(self.directory)
        assert player.isOpened()

        #code for writing video from frames
        x_shape = int(player.get(cv2.CAP_PROP_FRAME_WIDTH))
        y_shape = int(player.get(cv2.CAP_PROP_FRAME_HEIGHT))
        four_cc = cv2.VideoWriter_fourcc(*"MJPG")
        out = cv2.VideoWriter(self.out_file, four_cc, 20, (x_shape, y_shape))

        #loading custom trained yolov7 models
        self.model_bike = self.load_bike_model(self.bike_rider_model)
        self.model_npr = self.load_npr_model(self.helmet_npr_model)

        #loop till video completes prediction
        while True:          
            start_time = time()
            ret, frame = player.read()
            if not ret:
                break
            results = self.score_frame(frame)               #returns the labels and coordinates
            frame = self.plot_boxes(results, frame)         #returns plotted bounding box frames
            end_time = time()
            fps = 1/np.round(end_time - start_time, 3)
            print(f"Frames Per Second : {fps}")             #prints At what frames per second predicting
            out.write(frame)                                #writes the predicted frame to video



video = input("Enter video directory: ") 

pred_directory = input("Directory to save the video with file name .mp4 extension: ")

# Create a new object and execute.
detection = ObjectDetection(video, pred_directory, bike_rider_model ='/content/drive/MyDrive/bike_rider_v7.pt', helmet_npr_model= '/content/drive/MyDrive/helmet_npr_v7.pt')
detection()
# Out:
# Device Used: cuda
# Downloading: "https://github.com/WongKinYiu/yolov7/zipball/main" to /root/.cache/torch/hub/main.zip
# Adding autoShape...
# Downloading: "https://github.com/WongKinYiu/yolov7/zipball/main" to /root/.cache/torch/hub/main.zip
# Adding autoShape...
# Frames Per Second : 4.484304932735426
# Frames Per Second : 5.847953216374268
# Frames Per Second : 5.617977528089888
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.813953488372094
# Frames Per Second : 5.319148936170213
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 6.849315068493151
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.329113924050633
# Frames Per Second : 7.246376811594202
# Frames Per Second : 6.5359477124183005
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.142857142857142
# Frames Per Second : 6.944444444444445
# Frames Per Second : 4.504504504504505
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 6.0606060606060606
# Frames Per Second : 5.154639175257731
# Frames Per Second : 6.0606060606060606
# Frames Per Second : 4.739336492890995
# Frames Per Second : 6.172839506172839
# Frames Per Second : 4.739336492890995
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 5.74712643678161
# Frames Per Second : 5.46448087431694
# Frames Per Second : 6.944444444444445
# Frames Per Second : 9.00900900900901
# Frames Per Second : 6.7114093959731544
# Frames Per Second : 7.352941176470588
# Frames Per Second : 5.813953488372094
# Frames Per Second : 7.092198581560284
# Frames Per Second : 4.62962962962963
# Frames Per Second : 5.2356020942408374
# Frames Per Second : 4.830917874396135
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 5.714285714285714
# Frames Per Second : 5.617977528089888
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.154639175257731
# Frames Per Second : 4.8543689320388355
# Frames Per Second : 6.097560975609756
# Frames Per Second : 5.4945054945054945
# Frames Per Second : 6.0606060606060606
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.7114093959731544
# Frames Per Second : 6.993006993006993
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.802721088435375
# Frames Per Second : 6.7114093959731544
# Frames Per Second : 6.622516556291391
# Frames Per Second : 6.097560975609756
# Frames Per Second : 6.578947368421053
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.756756756756757
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 5.555555555555555
# Frames Per Second : 5.649717514124294
# Frames Per Second : 7.246376811594202
# Frames Per Second : 7.142857142857142
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.666666666666667
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 6.451612903225807
# Frames Per Second : 7.352941176470588
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.194244604316546
# Frames Per Second : 8.264462809917356
# Frames Per Second : 9.00900900900901
# Frames Per Second : 5.988023952095808
# Frames Per Second : 6.369426751592357
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.352941176470588
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.756756756756757
# Frames Per Second : 5.714285714285714
# Frames Per Second : 4.545454545454546
# Frames Per Second : 4.11522633744856
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.74712643678161
# Frames Per Second : 3.125
# Frames Per Second : 4.8543689320388355
# Frames Per Second : 6.134969325153374
# Frames Per Second : 5.847953216374268
# Frames Per Second : 6.134969325153374
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 5.319148936170213
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 4.878048780487805
# Frames Per Second : 4.901960784313726
# Frames Per Second : 5.05050505050505
# Frames Per Second : 4.587155963302752
# Frames Per Second : 4.975124378109452
# Frames Per Second : 5.128205128205128
# Frames Per Second : 5.025125628140703
# Frames Per Second : 5.128205128205128
# Frames Per Second : 4.901960784313726
# Frames Per Second : 5.291005291005291
# Frames Per Second : 6.097560975609756
# Frames Per Second : 5.555555555555555
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 5.05050505050505
# Frames Per Second : 5.128205128205128
# Frames Per Second : 5.291005291005291
# Frames Per Second : 5.154639175257731
# Frames Per Second : 5.555555555555555
# Frames Per Second : 4.926108374384236
# Frames Per Second : 5.05050505050505
# Frames Per Second : 5.0
# Frames Per Second : 5.0
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 5.649717514124294
# Frames Per Second : 5.319148936170213
# Frames Per Second : 5.128205128205128
# Frames Per Second : 5.025125628140703
# Frames Per Second : 5.154639175257731
# Frames Per Second : 5.025125628140703
# Frames Per Second : 5.128205128205128
# Frames Per Second : 5.025125628140703
# Frames Per Second : 5.025125628140703
# Frames Per Second : 4.926108374384236
# Frames Per Second : 4.545454545454546
# Frames Per Second : 4.926108374384236
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 5.128205128205128
# Frames Per Second : 4.545454545454546
# Frames Per Second : 4.25531914893617
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 4.545454545454546
# Frames Per Second : 4.504504504504505
# Frames Per Second : 4.201680672268908
# Frames Per Second : 4.464285714285714
# Frames Per Second : 4.504504504504505
# Frames Per Second : 4.11522633744856
# Frames Per Second : 4.065040650406504
# Frames Per Second : 4.273504273504273
# Frames Per Second : 4.3478260869565215
# Frames Per Second : 4.3478260869565215
# Frames Per Second : 4.385964912280701
# Frames Per Second : 4.784688995215311
# Frames Per Second : 5.05050505050505
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 5.025125628140703
# Frames Per Second : 4.830917874396135
# Frames Per Second : 4.761904761904762
# Frames Per Second : 5.2631578947368425
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 4.484304932735426
# Frames Per Second : 4.739336492890995
# Frames Per Second : 4.926108374384236
# Frames Per Second : 4.8076923076923075
# Frames Per Second : 4.975124378109452
# Frames Per Second : 5.128205128205128
# Frames Per Second : 4.8543689320388355
# Frames Per Second : 5.847953216374268
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.0606060606060606
# Frames Per Second : 7.462686567164178
# Frames Per Second : 7.042253521126761
# Frames Per Second : 6.993006993006993
# Frames Per Second : 8.928571428571429
# Frames Per Second : 5.813953488372094
# Frames Per Second : 5.376344086021505
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.4945054945054945
# Frames Per Second : 7.042253521126761
# Frames Per Second : 5.952380952380952
# Frames Per Second : 4.926108374384236
# Frames Per Second : 6.024096385542168
# Frames Per Second : 4.3478260869565215
# Frames Per Second : 4.901960784313726
# Frames Per Second : 5.988023952095808
# Frames Per Second : 5.780346820809249
# Frames Per Second : 5.813953488372094
# Frames Per Second : 7.092198581560284
# Frames Per Second : 5.617977528089888
# Frames Per Second : 6.134969325153374
# Frames Per Second : 6.134969325153374
# Frames Per Second : 6.134969325153374
# Frames Per Second : 4.901960784313726
# Frames Per Second : 4.8543689320388355
# Frames Per Second : 4.975124378109452
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 4.385964912280701
# Frames Per Second : 4.273504273504273
# Frames Per Second : 4.366812227074235
# Frames Per Second : 4.484304932735426
# Frames Per Second : 4.366812227074235
# Frames Per Second : 4.366812227074235
# Frames Per Second : 4.651162790697675
# Frames Per Second : 4.587155963302752
# Frames Per Second : 5.319148936170213
# Frames Per Second : 5.181347150259067
# Frames Per Second : 5.376344086021505
# Frames Per Second : 4.901960784313726
# Frames Per Second : 5.05050505050505
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.05050505050505
# Frames Per Second : 6.134969325153374
# Frames Per Second : 4.366812227074235
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 4.901960784313726
# Frames Per Second : 5.154639175257731
# Frames Per Second : 5.181347150259067
# Frames Per Second : 5.74712643678161
# Frames Per Second : 5.714285714285714
# Frames Per Second : 6.211180124223603
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 6.25
# Frames Per Second : 5.46448087431694
# Frames Per Second : 5.2356020942408374
# Frames Per Second : 4.830917874396135
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 4.484304932735426
# Frames Per Second : 5.58659217877095
# Frames Per Second : 6.849315068493151
# Frames Per Second : 6.097560975609756
# Frames Per Second : 6.578947368421053
# Frames Per Second : 7.194244604316546
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 6.578947368421053
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 6.097560975609756
# Frames Per Second : 5.376344086021505
# Frames Per Second : 5.46448087431694
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.246376811594202
# Frames Per Second : 6.993006993006993
# Frames Per Second : 6.993006993006993
# Frames Per Second : 6.756756756756757
# Frames Per Second : 4.739336492890995
# Frames Per Second : 6.0606060606060606
# Frames Per Second : 5.405405405405405
# Frames Per Second : 6.134969325153374
# Frames Per Second : 4.975124378109452
# Frames Per Second : 4.651162790697675
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 4.926108374384236
# Frames Per Second : 5.208333333333333
# Frames Per Second : 4.366812227074235
# Frames Per Second : 4.132231404958678
# Frames Per Second : 5.988023952095808
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 6.0606060606060606
# Frames Per Second : 5.0
# Frames Per Second : 6.4935064935064934
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.142857142857142
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.042253521126761
# Frames Per Second : 6.211180124223603
# Frames Per Second : 7.751937984496124
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.944444444444445
# Frames Per Second : 5.952380952380952
# Frames Per Second : 7.246376811594202
# Frames Per Second : 5.405405405405405
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.134969325153374
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.142857142857142
# Frames Per Second : 4.761904761904762
# Frames Per Second : 5.0
# Frames Per Second : 7.246376811594202
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 5.025125628140703
# Frames Per Second : 4.739336492890995
# Frames Per Second : 4.830917874396135
# Frames Per Second : 4.975124378109452
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.802721088435375
# Frames Per Second : 8.771929824561402
# Frames Per Second : 8.130081300813009
# Frames Per Second : 8.130081300813009
# Frames Per Second : 6.7114093959731544
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.4935064935064934
# Frames Per Second : 7.092198581560284
# Frames Per Second : 5.58659217877095
# Frames Per Second : 7.042253521126761
# Frames Per Second : 5.4945054945054945
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.813953488372094
# Frames Per Second : 5.988023952095808
# Frames Per Second : 5.4945054945054945
# Frames Per Second : 5.58659217877095
# Frames Per Second : 6.7114093959731544
# Frames Per Second : 6.802721088435375
# Frames Per Second : 5.714285714285714
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 6.5359477124183005
# Frames Per Second : 8.547008547008547
# Frames Per Second : 6.211180124223603
# Frames Per Second : 6.993006993006993
# Frames Per Second : 6.993006993006993
# Frames Per Second : 9.00900900900901
# Frames Per Second : 10.204081632653061
# Frames Per Second : 8.264462809917356
# Frames Per Second : 8.547008547008547
# Frames Per Second : 8.547008547008547
# Frames Per Second : 6.622516556291391
# Frames Per Second : 6.849315068493151
# Frames Per Second : 6.944444444444445
# Frames Per Second : 8.771929824561402
# Frames Per Second : 5.46448087431694
# Frames Per Second : 6.410256410256411
# Frames Per Second : 6.802721088435375
# Frames Per Second : 6.849315068493151
# Frames Per Second : 5.988023952095808
# Frames Per Second : 5.649717514124294
# Frames Per Second : 5.58659217877095
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.847953216374268
# Frames Per Second : 6.802721088435375
# Frames Per Second : 5.988023952095808
# Frames Per Second : 8.0
# Frames Per Second : 7.8125
# Frames Per Second : 8.928571428571429
# Frames Per Second : 8.928571428571429
# Frames Per Second : 12.195121951219512
# Frames Per Second : 11.76470588235294
# Frames Per Second : 15.873015873015873
# Frames Per Second : 17.241379310344826
# Frames Per Second : 11.363636363636365
# Frames Per Second : 15.15151515151515
# Frames Per Second : 16.666666666666668
# Frames Per Second : 17.241379310344826
# Frames Per Second : 10.416666666666666
# Frames Per Second : 11.904761904761903
# Frames Per Second : 12.345679012345679
# Frames Per Second : 11.363636363636365
# Frames Per Second : 11.904761904761903
# Frames Per Second : 11.363636363636365
# Frames Per Second : 11.49425287356322
# Frames Per Second : 11.904761904761903
# Frames Per Second : 10.638297872340425
# Frames Per Second : 8.620689655172413
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.333333333333334
# Frames Per Second : 8.928571428571429
# Frames Per Second : 7.874015748031496
# Frames Per Second : 8.620689655172413
# Frames Per Second : 8.130081300813009
# Frames Per Second : 9.090909090909092
# Frames Per Second : 8.264462809917356
# Frames Per Second : 8.0
# Frames Per Second : 8.771929824561402
# Frames Per Second : 9.174311926605505
# Frames Per Second : 7.874015748031496
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.042253521126761
# Frames Per Second : 6.410256410256411
# Frames Per Second : 7.194244604316546
# Frames Per Second : 7.194244604316546
# Frames Per Second : 5.291005291005291
# Frames Per Second : 5.780346820809249
# Frames Per Second : 7.092198581560284
# Frames Per Second : 5.555555555555555
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.666666666666667
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.695652173913043
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 7.246376811594202
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.756756756756757
# Frames Per Second : 8.695652173913043
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.142857142857142
# Frames Per Second : 7.575757575757575
# Frames Per Second : 7.246376811594202
# Frames Per Second : 8.695652173913043
# Frames Per Second : 8.620689655172413
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.620689655172413
# Frames Per Second : 8.547008547008547
# Frames Per Second : 8.771929824561402
# Frames Per Second : 9.25925925925926
# Frames Per Second : 8.695652173913043
# Frames Per Second : 8.849557522123893
# Frames Per Second : 6.5359477124183005
# Frames Per Second : 6.666666666666667
# Frames Per Second : 5.714285714285714
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.46448087431694
# Frames Per Second : 5.524861878453039
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.756756756756757
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.849315068493151
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.352941176470588
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.993006993006993
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 6.024096385542168
# Frames Per Second : 7.194244604316546
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.024096385542168
# Frames Per Second : 5.0
# Frames Per Second : 6.289308176100628
# Frames Per Second : 5.524861878453039
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 6.5359477124183005
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.849315068493151
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.142857142857142
# Frames Per Second : 7.142857142857142
# Frames Per Second : 5.88235294117647
# Frames Per Second : 7.246376811594202
# Frames Per Second : 6.410256410256411
# Frames Per Second : 6.756756756756757
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.849315068493151
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.4935064935064934
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 5.813953488372094
# Frames Per Second : 5.74712643678161
# Frames Per Second : 5.88235294117647
# Frames Per Second : 6.25
# Frames Per Second : 5.780346820809249
# Frames Per Second : 5.714285714285714
# Frames Per Second : 5.847953216374268
# Frames Per Second : 6.024096385542168
# Frames Per Second : 5.988023952095808
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.802721088435375
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.142857142857142
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.993006993006993
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.462686567164178
# Frames Per Second : 6.451612903225807
# Frames Per Second : 7.142857142857142
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 7.142857142857142
# Frames Per Second : 7.142857142857142
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.246376811594202
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.2992700729927
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.849315068493151
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.756756756756757
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.451612903225807
# Frames Per Second : 6.622516556291391
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.042253521126761
# Frames Per Second : 6.5359477124183005
# Frames Per Second : 6.993006993006993
# Frames Per Second : 6.849315068493151
# Frames Per Second : 6.289308176100628
# Frames Per Second : 7.142857142857142
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.7114093959731544
# Frames Per Second : 6.097560975609756
# Frames Per Second : 6.802721088435375
# Frames Per Second : 6.849315068493151
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.2992700729927
# Frames Per Second : 5.88235294117647
# Frames Per Second : 6.802721088435375
# Frames Per Second : 6.756756756756757
# Frames Per Second : 6.666666666666667
# Frames Per Second : 7.2992700729927
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.246376811594202
# Frames Per Second : 5.813953488372094
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.813953488372094
# Frames Per Second : 6.024096385542168
# Frames Per Second : 6.0606060606060606
# Frames Per Second : 5.847953216374268
# Frames Per Second : 5.649717514124294
# Frames Per Second : 5.347593582887701
# Frames Per Second : 6.024096385542168
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.952380952380952
# Frames Per Second : 6.024096385542168
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.714285714285714
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 5.847953216374268
# Frames Per Second : 5.88235294117647
# Frames Per Second : 4.201680672268908
# Frames Per Second : 4.11522633744856
# Frames Per Second : 4.3478260869565215
# Frames Per Second : 4.3478260869565215
# Frames Per Second : 4.201680672268908
# Frames Per Second : 3.731343283582089
# Frames Per Second : 4.166666666666667
# Frames Per Second : 4.184100418410042
# Frames Per Second : 4.201680672268908
# Frames Per Second : 4.310344827586206
# Frames Per Second : 4.237288135593221
# Frames Per Second : 4.25531914893617
# Frames Per Second : 3.937007874015748
# Frames Per Second : 4.878048780487805
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.194244604316546
# Frames Per Second : 6.802721088435375
# Frames Per Second : 7.092198581560284
# Frames Per Second : 7.142857142857142
# Frames Per Second : 4.184100418410042
# Frames Per Second : 4.405286343612334
# Frames Per Second : 4.504504504504505
# Frames Per Second : 4.566210045662101
# Frames Per Second : 4.273504273504273
# Frames Per Second : 4.524886877828054
# Frames Per Second : 5.291005291005291
# Frames Per Second : 5.128205128205128
# Frames Per Second : 5.154639175257731
# Frames Per Second : 4.878048780487805
# Frames Per Second : 4.464285714285714
# Frames Per Second : 4.464285714285714
# Frames Per Second : 4.504504504504505
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 5.05050505050505
# Frames Per Second : 5.434782608695652
# Frames Per Second : 5.208333333333333
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 5.376344086021505
# Frames Per Second : 5.649717514124294
# Frames Per Second : 5.05050505050505
# Frames Per Second : 5.0
# Frames Per Second : 4.424778761061947
# Frames Per Second : 4.184100418410042
# Frames Per Second : 4.566210045662101
# Frames Per Second : 4.784688995215311
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 5.405405405405405
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 5.617977528089888
# Frames Per Second : 4.9504950495049505
# Frames Per Second : 16.666666666666668
# Frames Per Second : 15.873015873015873
# Frames Per Second : 16.129032258064516
# Frames Per Second : 11.363636363636365
# Frames Per Second : 6.5359477124183005
# Frames Per Second : 8.547008547008547
# Frames Per Second : 16.39344262295082
# Frames Per Second : 11.363636363636365
# Frames Per Second : 10.526315789473685
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.849557522123893
# Frames Per Second : 7.092198581560284
# Frames Per Second : 6.993006993006993
# Frames Per Second : 8.333333333333334
# Frames Per Second : 7.194244604316546
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.620689655172413
# Frames Per Second : 8.928571428571429
# Frames Per Second : 7.936507936507937
# Frames Per Second : 8.264462809917356
# Frames Per Second : 8.130081300813009
# Frames Per Second : 8.771929824561402
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.547008547008547
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.849557522123893
# Frames Per Second : 17.543859649122805
# Frames Per Second : 8.064516129032258
# Frames Per Second : 11.76470588235294
# Frames Per Second : 17.857142857142858
# Frames Per Second : 16.39344262295082
# Frames Per Second : 17.857142857142858
# Frames Per Second : 11.235955056179776
# Frames Per Second : 10.204081632653061
# Frames Per Second : 11.49425287356322
# Frames Per Second : 17.543859649122805
# Frames Per Second : 8.474576271186441
# Frames Per Second : 11.904761904761903
# Frames Per Second : 11.76470588235294
# Frames Per Second : 8.849557522123893
# Frames Per Second : 8.547008547008547
# Frames Per Second : 6.944444444444445
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.264462809917356
# Frames Per Second : 8.849557522123893
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.264462809917356
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.695652173913043
# Frames Per Second : 8.849557522123893
# Frames Per Second : 8.849557522123893
# Frames Per Second : 8.064516129032258
# Frames Per Second : 11.49425287356322
# Frames Per Second : 17.241379310344826
# Frames Per Second : 11.363636363636365
# Frames Per Second : 10.416666666666666
# Frames Per Second : 11.49425287356322
# Frames Per Second : 11.904761904761903
# Frames Per Second : 11.627906976744187
# Frames Per Second : 11.49425287356322
# Frames Per Second : 11.627906976744187
# Frames Per Second : 11.76470588235294
# Frames Per Second : 11.11111111111111
# Frames Per Second : 16.129032258064516
# Frames Per Second : 15.625
# Frames Per Second : 15.625
# Frames Per Second : 16.129032258064516
# Frames Per Second : 6.666666666666667
# Frames Per Second : 6.993006993006993
# Frames Per Second : 4.651162790697675
# Frames Per Second : 4.926108374384236
# Frames Per Second : 4.424778761061947
# Frames Per Second : 4.201680672268908
# Frames Per Second : 4.9504950495049505
# Frames Per Second : 4.8543689320388355
# Frames Per Second : 4.184100418410042
# Frames Per Second : 4.291845493562231
# Frames Per Second : 4.651162790697675
# Frames Per Second : 4.184100418410042
# Frames Per Second : 4.9504950495049505
# Frames Per Second : 5.617977528089888
# Frames Per Second : 4.784688995215311
# Frames Per Second : 5.74712643678161
# Frames Per Second : 6.7114093959731544
# Frames Per Second : 4.9504950495049505
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.208333333333333
# Frames Per Second : 7.194244604316546
# Frames Per Second : 5.714285714285714
# Frames Per Second : 5.617977528089888
# Frames Per Second : 5.58659217877095
# Frames Per Second : 5.6818181818181825
# Frames Per Second : 5.555555555555555
# Frames Per Second : 7.042253521126761
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 5.9171597633136095
# Frames Per Second : 5.780346820809249
# Frames Per Second : 5.434782608695652
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.434782608695652
# Frames Per Second : 5.74712643678161
# Frames Per Second : 5.952380952380952
# Frames Per Second : 6.451612903225807
# Frames Per Second : 6.802721088435375
# Frames Per Second : 8.264462809917356
# Frames Per Second : 7.8125
# Frames Per Second : 8.547008547008547
# Frames Per Second : 6.666666666666667
# Frames Per Second : 6.944444444444445
# Frames Per Second : 7.042253521126761
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.142857142857142
# Frames Per Second : 5.524861878453039
# Frames Per Second : 6.944444444444445
# Frames Per Second : 5.714285714285714
# Frames Per Second : 8.928571428571429
# Frames Per Second : 6.451612903225807
# Frames Per Second : 7.142857142857142
# Frames Per Second : 6.849315068493151
# Frames Per Second : 8.620689655172413
# Frames Per Second : 7.692307692307692
# Frames Per Second : 6.944444444444445
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.064516129032258
# Frames Per Second : 8.620689655172413
# Frames Per Second : 11.363636363636365
# Frames Per Second : 10.416666666666666
# Frames Per Second : 16.666666666666668
# Frames Per Second : 16.129032258064516
# Frames Per Second : 15.625
# Frames Per Second : 15.873015873015873
# Frames Per Second : 15.15151515151515
# Frames Per Second : 15.625
# Frames Per Second : 11.235955056179776
# Frames Per Second : 10.204081632653061
# Frames Per Second : 16.949152542372882
# Frames Per Second : 17.241379310344826
# Frames Per Second : 15.873015873015873
# Frames Per Second : 16.129032258064516
# Frames Per Second : 11.235955056179776
# Frames Per Second : 10.869565217391305
# Frames Per Second : 17.543859649122805
# Frames Per Second : 17.241379310344826
# Frames Per Second : 16.129032258064516
# Frames Per Second : 16.129032258064516
# Frames Per Second : 16.39344262295082
# Frames Per Second : 14.925373134328357
# Frames Per Second : 14.705882352941176
# Frames Per Second : 16.129032258064516
# Frames Per Second : 16.39344262295082
# Frames Per Second : 16.666666666666668
# Frames Per Second : 11.363636363636365
# Frames Per Second : 8.620689655172413
# Frames Per Second : 8.333333333333334
# Frames Per Second : 8.333333333333334
# Frames Per Second : 10.869565217391305
# Frames Per Second : 11.235955056179776
# Frames Per Second : 10.0
# Frames Per Second : 10.309278350515463
# Frames Per Second : 10.869565217391305
# Frames Per Second : 8.064516129032258
# Frames Per Second : 10.989010989010989
# Frames Per Second : 10.416666666666666
# Frames Per Second : 10.1010101010101
# Frames Per Second : 10.1010101010101
# Frames Per Second : 8.264462809917356
# Frames Per Second : 9.00900900900901
# Frames Per Second : 10.869565217391305
# Frames Per Second : 9.615384615384615
# Frames Per Second : 10.638297872340425
# Frames Per Second : 7.936507936507937
# Frames Per Second : 11.11111111111111
# Frames Per Second : 10.989010989010989
# Frames Per Second : 10.869565217391305
# Frames Per Second : 10.416666666666666
# Frames Per Second : 10.75268817204301
# Frames Per Second : 8.547008547008547
# Frames Per Second : 7.8125
# Frames Per Second : 10.0
# Frames Per Second : 10.75268817204301
# Frames Per Second : 8.130081300813009
# Frames Per Second : 8.474576271186441
# Frames Per Second : 7.633587786259541
# Frames Per Second : 8.333333333333334
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.695652173913043
# Frames Per Second : 8.130081300813009
# Frames Per Second : 9.00900900900901
# Frames Per Second : 8.0
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.695652173913043
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.695652173913043
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.547008547008547
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.547008547008547
# Frames Per Second : 8.333333333333334
# Frames Per Second : 10.989010989010989
# Frames Per Second : 11.235955056179776
# Frames Per Second : 10.75268817204301
# Frames Per Second : 8.333333333333334
# Frames Per Second : 8.547008547008547
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.474576271186441
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.264462809917356
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.064516129032258
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.403361344537815
# Frames Per Second : 8.064516129032258
# Frames Per Second : 6.993006993006993
# Frames Per Second : 7.751937984496124
# Frames Per Second : 9.345794392523365
# Frames Per Second : 7.518796992481203
# Frames Per Second : 7.936507936507937
# Frames Per Second : 8.0
# Frames Per Second : 11.49425287356322
# Frames Per Second : 11.235955056179776
# Frames Per Second : 10.526315789473685
# Frames Per Second : 10.1010101010101
# Frames Per Second : 11.11111111111111
# Frames Per Second : 4.784688995215311
# Frames Per Second : 4.878048780487805
# Frames Per Second : 5.0
# Frames Per Second : 4.784688995215311
# Frames Per Second : 4.975124378109452
# Frames Per Second : 4.761904761904762
# Frames Per Second : 5.0
# Frames Per Second : 5.780346820809249
# Frames Per Second : 5.813953488372094
# Frames Per Second : 5.58659217877095
# Frames Per Second : 4.878048780487805
# Frames Per Second : 4.761904761904762
# Frames Per Second : 4.926108374384236
# Frames Per Second : 4.8076923076923075
# Frames Per Second : 4.784688995215311
# Frames Per Second : 4.761904761904762
# Frames Per Second : 4.716981132075472
# Frames Per Second : 4.784688995215311
# Frames Per Second : 4.901960784313726
# Frames Per Second : 4.761904761904762
# Frames Per Second : 4.201680672268908
# Frames Per Second : 4.385964912280701
# Frames Per Second : 4.366812227074235
# Frames Per Second : 4.032258064516129
# Frames Per Second : 4.405286343612334
# Frames Per Second : 3.861003861003861
# Frames Per Second : 3.937007874015748
# Frames Per Second : 4.149377593360996
# Frames Per Second : 4.291845493562231
# Frames Per Second : 4.184100418410042
# Frames Per Second : 5.128205128205128
# Frames Per Second : 4.8076923076923075
# Frames Per Second : 4.761904761904762
# Frames Per Second : 4.716981132075472
# Frames Per Second : 5.1020408163265305
# Frames Per Second : 4.8543689320388355
# Frames Per Second : 4.6082949308755765
# Frames Per Second : 4.694835680751174
# Frames Per Second : 5.05050505050505
# Frames Per Second : 4.901960784313726
# Frames Per Second : 4.784688995215311
# Frames Per Second : 4.784688995215311
# Frames Per Second : 4.672897196261682
# Frames Per Second : 3.6363636363636362
# Frames Per Second : 3.4246575342465757
# Frames Per Second : 3.558718861209964
# Frames Per Second : 3.4602076124567476
# Frames Per Second : 3.436426116838488
# Frames Per Second : 3.3003300330033003
# Frames Per Second : 3.1545741324921135
# Frames Per Second : 3.2679738562091503
# Frames Per Second : 4.065040650406504
# Frames Per Second : 3.663003663003663
# Frames Per Second : 3.367003367003367
# Frames Per Second : 3.9682539682539684
# Frames Per Second : 5.780346820809249
# Frames Per Second : 5.46448087431694
# Frames Per Second : 5.291005291005291
# Frames Per Second : 4.975124378109452
# Frames Per Second : 4.830917874396135
# Frames Per Second : 4.716981132075472
# Frames Per Second : 5.952380952380952
# Frames Per Second : 5.649717514124294
# Frames Per Second : 5.88235294117647
# Frames Per Second : 4.739336492890995
# Frames Per Second : 4.9504950495049505
# Frames Per Second : 4.739336492890995
# Frames Per Second : 4.926108374384236
# Frames Per Second : 5.88235294117647
# Frames Per Second : 5.58659217877095
# Frames Per Second : 6.5359477124183005
# Frames Per Second : 5.154639175257731
# Frames Per Second : 5.952380952380952
# Frames Per Second : 6.4935064935064934
# Frames Per Second : 6.993006993006993
# Frames Per Second : 6.849315068493151
# Frames Per Second : 5.617977528089888
# Frames Per Second : 6.211180124223603
# Frames Per Second : 9.00900900900901
# Frames Per Second : 8.130081300813009
# Frames Per Second : 7.2992700729927
# Frames Per Second : 8.771929824561402
# Frames Per Second : 8.333333333333334
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.0
# Frames Per Second : 6.849315068493151
# Frames Per Second : 7.246376811594202
# Frames Per Second : 6.993006993006993
# Frames Per Second : 8.620689655172413
# Frames Per Second : 6.802721088435375
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 7.936507936507937
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 7.042253521126761
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 8.333333333333334
# Frames Per Second : 11.904761904761903
# Frames Per Second : 9.900990099009901
# Frames Per Second : 10.869565217391305
# Frames Per Second : 6.410256410256411
# Frames Per Second : 9.00900900900901
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.771929824561402
# Frames Per Second : 6.944444444444445
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 6.666666666666667
# Frames Per Second : 7.246376811594202
# Frames Per Second : 9.25925925925926
# Frames Per Second : 6.8965517241379315
# Frames Per Second : 7.2992700729927
# Frames Per Second : 8.264462809917356
# Frames Per Second : 8.620689655172413
# Frames Per Second : 6.410256410256411
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 8.695652173913043
# Frames Per Second : 9.090909090909092
# Frames Per Second : 8.19672131147541
# Frames Per Second : 8.620689655172413
# Frames Per Second : 8.333333333333334
# Frames Per Second : 5.58659217877095
# Frames Per Second : 5.0761421319796955
# Frames Per Second : 5.05050505050505
# Frames Per Second : 7.4074074074074066
# Frames Per Second : 5.6818181818181825
